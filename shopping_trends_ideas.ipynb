# %% [markdown]
# # Customer Shopping Trends
# Source: https://www.kaggle.com/datasets/iamsouravbanerjee/customer-shopping-trends-dataset?select=shopping_trends_updated.csv

# %% [markdown]
# ### possible scenario:
# - a major retailer has recently gathered a large amount of data about its customers' shopping trends. we have been hired as consultants to process this data, identify existing trends and match them to what they see in revenue, investigate shortcomings, and make recommendations for improvement.
#
# ### questions:
# **me**
# 1. What are the most common items purchased by customers aged 18-25? + look at male and females
# 2. What is the average purchase amount for female customers in different age groups?
# 3.
#
# **Juan**
# 3. What is the preferred payment method for customers who have subscriptions?
# 4. Did customers who used discounts or promo codes give higher review ratings compared to those who didn't?
# 5. What items are popular during a specific season
#
# **Zalen**
# 1.

# %% [markdown]
# ## Data Acquisition
# preview of `shopping_trends_updated.csv`:

# %%
import pandas as pd
# create dataframe
shopping = pd.read_csv("shopping_trends/shopping_trends_updated.csv")
# display a preview
shopping.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# #### display the number of cols, rows

# %%
# print the shape
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\nThere are " + str(shopping.shape[1]) + " columns and " + str(shopping.shape[0]) + " rows.\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# There are 18 columns and 3900 rows.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# #### check the data types:

# %%
# prints variable data types
shopping.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %% [markdown]
# #### find out how many unique values are in categorical cols (where possible):

# %%
# display the number of uniques for each categorical column, where it makes sense
print("There are " + str(shopping['Gender'].nunique()) + " different genders in `Gender`.")
print("There are " + str(shopping['Item Purchased'].nunique()) + " different items purchased in `Item Purchased`.")
print("There are " + str(shopping['Category'].nunique()) + " different categories in `Category`.")
print("There are " + str(shopping['Location'].nunique()) + " different locations in `Location`.")
print("There are " + str(shopping['Size'].nunique()) + " different sizes in `Size`.")
print("There are " + str(shopping['Color'].nunique()) + " different colors in `Color`.")
print("There are " + str(shopping['Season'].nunique()) + " different seasons in `Season`.")
print("There are " + str(shopping['Subscription Status'].nunique()) + " different subscription statuses in `Subscription Status`.")
print("There are " + str(shopping['Shipping Type'].nunique()) + " different shipping types in `Shipping Type`.")
print("There are " + str(shopping['Discount Applied'].nunique()) + " different discounts applied in `Discount Applied`.")
print("There are " + str(shopping['Promo Code Used'].nunique()) + " different promo codes used in `Promo Code Used`.")
print("There are " + str(shopping['Payment Method'].nunique()) + " different payment methods in `Payment Method`.")
print("There are " + str(shopping['Frequency of Purchases'].nunique()) + " different frequencies of purchases in `Frequency of Purchases`.")
# Out:
# There are 2 different genders in `Gender`.
# There are 25 different items purchased in `Item Purchased`.
# There are 4 different categories in `Category`.
# There are 50 different locations in `Location`.
# There are 4 different sizes in `Size`.
# There are 25 different colors in `Color`.
# There are 4 different seasons in `Season`.
# There are 2 different subscription statuses in `Subscription Status`.
# There are 6 different shipping types in `Shipping Type`.
# There are 2 different discounts applied in `Discount Applied`.
# There are 2 different promo codes used in `Promo Code Used`.
# There are 6 different payment methods in `Payment Method`.
# There are 7 different frequencies of purchases in `Frequency of Purchases`.

# %% [markdown]
# #### find out what the unique values are (where possible):

# %%
# get the unique values where it makes sense
print("Unique values in `Gender`:\n", shopping['Gender'].unique())
print("\nUnique values in `Item Purchased`:\n", shopping['Item Purchased'].unique())
print("\nUnique values in `Category`:\n", shopping['Category'].unique())
print("\nUnique values in `Location`:\n", shopping['Location'].unique())
print("\nUnique values in `Size`:\n", shopping['Size'].unique())
print("\nUnique values in `Color`:\n", shopping['Color'].unique())
print("\nUnique values in `Season`:\n", shopping['Season'].unique())
print("\nUnique values in `Subscription Status`:\n", shopping['Subscription Status'].unique())
print("\nUnique values in `Shipping Type`:\n", shopping['Shipping Type'].unique())
print("\nUnique values in `Discount Applied`:\n", shopping['Discount Applied'].unique())
print("\nUnique values in `Promo Code Used`:\n", shopping['Promo Code Used'].unique())
print("\nUnique values in `Payment Method`:\n", shopping['Payment Method'].unique())
print("\nUnique values in `Frequency of Purchases`:\n", shopping['Frequency of Purchases'].unique())
# Out:
# Unique values in `Gender`:
#  ['Male' 'Female']
#
# Unique values in `Item Purchased`:
#  ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
#  'Jewelry' 'T-shirt' 'Scarf' 'Hat' 'Socks' 'Backpack' 'Belt' 'Boots'
#  'Gloves']
#
# Unique values in `Category`:
#  ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
#
# Unique values in `Location`:
#  ['Kentucky' 'Maine' 'Massachusetts' 'Rhode Island' 'Oregon' 'Wyoming'
#  'Montana' 'Louisiana' 'West Virginia' 'Missouri' 'Arkansas' 'Hawaii'
#  'Delaware' 'New Hampshire' 'New York' 'Alabama' 'Mississippi'
#  'North Carolina' 'California' 'Oklahoma' 'Florida' 'Texas' 'Nevada'
#  'Kansas' 'Colorado' 'North Dakota' 'Illinois' 'Indiana' 'Arizona'
#  'Alaska' 'Tennessee' 'Ohio' 'New Jersey' 'Maryland' 'Vermont'
#  'New Mexico' 'South Carolina' 'Idaho' 'Pennsylvania' 'Connecticut' 'Utah'
# ...

# %% [markdown]
# #### check for missing values:

# %%
# check for missing values
missing_values = shopping.isnull().sum()

# calculate missing value counts for those columns where missing values are greater than zero
missing_values_df = pd.DataFrame(missing_values[missing_values > 0], columns=['Count Missing'])

# adjust the calculation for missing_pct
missing_pct = ((missing_values[missing_values > 0] / shopping.shape[0] * 100).round(3))

# add missing count and percent to table
missing_values_df["% Missing"] = missing_pct

# check if there are no missing values, and print a message if that's the case
if missing_values_df.empty:
    print("There are no missing values.")
else:
    # display the table if there are missing values
    display(missing_values_df)
# Out:
# There are no missing values.

# %% [markdown]
# #### check for duplicates:

# %%
# Check for duplicate rows
duplicate_rows = shopping.duplicated().sum()

# Get a boolean series indicating which rows are duplicates (including the original rows)
duplicate_mask_all = shopping.duplicated(keep=False)

# Use this mask to filter and display both the original and duplicate rows
duplicate_rows_all_df = shopping[duplicate_mask_all]
duplicate_rows_all_df

# check if there are no missing values, and print a message if that's the case
if duplicate_rows_all_df.empty:
    print("There are no duplicates.")
else:
    # display the table if there are missing values
    print("There are " + str(duplicate_rows) + " duplicate row(s).\n")
    display(duplicate_rows_all_df)
# Out:
# There are no duplicates.

# %% [markdown]
# #### basic statistics for the numerical columns:
# - the youngest customer is 18; the highest is 70
# - the lowest purchase amount is $20; the highest is $100
# -

# %%
# basic statistics for the numerical columns
shopping.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# ## Exploratory data analysis
# recall questions, for reference:
# 1. **Best-Selling Items and Categories by Demographic.** What are the most common items purchased by customers aged 18-25? + look at male and females
# - Looking at overall the count/percentage of total, which of the store's departments are most-shopped by different demographics? What items are best-selling for these customers?
# Single categories include: `Gender`, `Age Range`, `Category`, `Item Purchased`
# Examine representation of age and gender: `Gender` by `Age Range`
# For examining by `Gender`, categories include: `Category` by `Gender`
#                                                `Item Purchased` by `Gender`
# For examining by `Age Range`, categories include: `Category` by `Age Range`
#                                                   `Item Purchased` by `Age Range`
#
# Possible logistic regression for classification:
#
# - Add `Location` if time permits
#
# - Interesting results might be:
# A particular `Gender` and/or `Age Range`(s) appear to be more frequent shoppers in one or more response categories than the other groups, which are otherwise evenly distributed. We might recommend further analyses to figure out what marketing or product departments are doing *right* which causes such interest.
# A particular `Gender` and/or `Age Range`(s) appears to fall short of the rest. We might recommend further analyses to figure out what marketing or product departments *can improve upon* to boost representation in these groups.
#
# ***Summarizing Results:***
# The most common items for customers aged 18-25 are ___.
#
#
# 2. **Purchase Amount Demographic Analysis.** What is the average purchase amount for female customers in different age groups? Previous purchases?
# - Across the demographic categories, what is the distribution of purchase amounts? What about the number of previous purchases? From this, does it appear that any particular group differs significantly from others?
# *(Provided model conditions are satisfied),*
# Possible regression:
# Predictors include: `Previous Purchases`, `Purchase Amount (USD)`, `Age`, and other demographic categories
# Response includes:  `Previous Purchases`, `Purchase Amount (USD)`
#
# One-way ANOVA: `Gender` groups by `Purchase Amount (USD)`/ by `Previous Purchaases`
# >>> F-Test insignificant: avg amount spent for males and females are the same. / avg previous visits for males and females are the same.
# >>> F-test significant: look for CI's that don't cover 0 in pairwise test.
#
# One-way Anova: `Age Range` groups by `Purchase Amount (USD)`, then by `Previous Purchases`
# >>> F-Test insignificant: avg amount spent across ages is the same. / avg previous visits across ages are the same.
# >>> F-test significant: CI's that don't cover 0 in pairwise test indicate age ranges that spend differently / visit differently.
#
# One-way Anova: `Category` groups by `Purchase Amount (USD)`, then by `Previous Purchases`
# >>> F-Test insignificant: avg amount spent across categories is the same. / avg previous visits across categories are the same.
# >>> F-test significant: CI's that don't cover 0 in pairwise test indicate categories that bring differing revenue / return visits.
#
# One-way Anova: `Item Purchased` groups by `Purchase Amount (USD)`, then by `Previous Purchases`
# >>> F-Test insignificant: avg amount spent across items is the same. / avg previous visits across items are the same.
# >>> F-test significant: CI's that don't cover 0 in pairwise test indicate items that bring differing revenue / return visits.
#
# Two-way ANOVA: `Gender` and `Age Range` groups by `Purchase Amount (USD)`, then by `Previous Purchases`
# >>> F-Test insignificant: avg amount spent across genders, ages is the same. / avg previous visits across genders, ages are the same.
# >>> F-test significant: CI's that don't cover 0 in pairwise test indicate genders, ages that bring differing revenue / return visits.
#
# - Add `Location` if time permits
# - As a plus: add in additional predictor categories such as `Category` and/or `Item Purchased` to look for interaction effects.
#
# - Interesting results might be:
# A particular `Gender` and/or `Age Range`(s) appear to be associated with higher `Purchase Amount (USD)`(s) than other groups. Similarly to examination of the product interest, we might recommend further study into how the store attracts such interest (is it the good selection of products, use of coupons, competitive pricing, etc.) we could also model the purchase amount as a regression function of `Age` with various categories and look for interaction effects.
# A particular `Gender` and/or `Age Range`(s) appear to be associated with a higher number of `Previous Purchases`(s) than other groups. We could model the previous purchases as a function of `Age` with various categories and look for interaction effects.
# as well as higher `Purchase Amount (USD)`. Similarly to examination of the product interest, we might recommend further study into how the store attracts such interest (is it the good selection of products, use of coupons, competitive pricing, etc.)
#
# top purchases by category
# the purchase amount by category
#
# distribution of products purchased by returning customers
#
#
#
#
#
# 3. **Subscription Program Demographic Analysis.** What is the subscription status and frequency of purchases among the age groups, genders?
# - How many subscribers vs non-subscribers are there?
# >>> There are more subscribers than non-subscribers.
# - What is the demographic makeup of subscribers vs non-subscribers?
# >>> All subscribers are male, and the most common age group is 18-25.
# - What are subscribers' most common categories and items purchased?
# - Are subscribers and non-subscribers spending different amounts of money?
# - Do subscribers have higher numbers of previous purchases than non-subscribers (does having a subscription increase customer retention)?
# - What shipping method do subscribers most commonly use?
# - Which locations are subscribers vs non-subscribers most commonly in?
#
# - What are the most common frequencies of purchase?
#
#
#
# 4. **Shipping Type Analysis.** How do customers spend differently across the diffferent shipping types?
# - Which locations most commonly use which types of shipping?
# - For locations which more frequently use free shipping, are purchase amounts higher? are previous purchases higher?
# - For locations which more frequenltly use store pickup, are purchase amounts higher? are previous purchases higher?
# - Do we see differing ratings across the different shipping types?
#
#
# other ideas:
# - Cross-Generational Product Trends: Use ANOVA to compare how multiple generations (e.g., Baby Boomers, Gen X, Millennials, Gen Z) differ in their shopping patterns for the same products.
# - determine if customer ID repeats. if it does: consider scenario where
# - recommendation algorithms: "location, people in your area. by gender, more men than women purchase an item, recommend it to a man (more complex than this). by gender + age, if you are this age and this gender it matches you to the product 1. most commonly bought by your demographic, 2.
#
#
# - analysis for recommendation
# - analysis for

# %% [markdown]
# #### variable creation:
# create bins (by every 5 years) from `Age`:

# %%
# cut age into bins
bins = [17, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70]  # bin upper boundaries (including 17 will capture 18)
labels = ['18-25', '26-30', '31-35', '36-40', '41-45', '46-50', '51-55', '56-60', '61-65', '66-70']  # specify the categories

# bin the data; right=False will make ages equalling the upper bounds of a category fall into the category below it
shopping['Age Range'] = pd.cut(shopping['Age'], bins=bins, labels=labels, right=False)

# print to make sure it worked 
shopping['Age Range'].head()
# Out:
# 0    56-60
# 1    18-25
# 2    51-55
# 3    18-25
# 4    46-50
# Name: Age Range, dtype: category
# Categories (10, object): ['18-25' < '26-30' < '31-35' < '36-40' ... '51-55' < '56-60' < '61-65' < '66-70']

# %% [markdown]
# create bins () for `Purchase Amount (USD)`:

# %% [markdown]
# create bins () for `Previous Purchases`:

# %% [markdown]
# #### visualization
# **univariate:**
# - visualize the following:
# - countplots: x=`Age Range` (total number ✓, percent of total ✓)
# - countplots: x=`Gender` (total number ✓, percent of total ✓)
# - countplots: x=`Category` (total number ✓, percent of total ✓)
# - countplots: x=`Item Purchased` (total number ✓, percent of total ✓)
# - countplots: x=`Purchase Amount (USD)` (total number, percent of total)
# - countplots: x=`Previous Purchases` (total number, percent of total)
# - countplots: x=`Location` (total number, percent of total)
# - countplots: x=`Subscription Status` (total number, percent of total)
# - countplots: x=`Shipping Type` (total number, percent of total)
#
# **bivariate:**
# - barplot: x=`Gender`, hue=`Category`  OR (2,1) with ax[0]=Male, ax[1]=Female  ✓
# - barplot: x=`Gender`, hue=`Item Purchased`  OR (2,1) with ax[0]=Male, ax[1]=Female  ✓
#
# ✓
# - boxplot: x=`Gender`, y=`Purchase Amount (USD)` ✓
# - boxplot: x=`Gender`, y=`Previous Purchases`  ✓
# - boxplot: x=`Age Range`, y=`Purchase Amount (USD)` ✓
# - boxplot: x=`Age Range`, y=`Previous Purchases` ✓
#
# **multivariate:**
# -

# %% [markdown]
# In looking solely at `Age Range`, it appears that the most common shopper falls into the '18-25' age range.

# %%
# plotting distribution of ages
import matplotlib.pyplot as plt     # import necessary libraries 
import seaborn as sns
f, ax = plt.subplots(figsize=(10, 2))   # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Age Range", data=shopping, color='cyan', ax=ax) # establish the plot
ax.set_title('Number of customers by age range', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Age', weight='bold', style='italic', size=12)                 # x label
ax.set_ylabel('Customer Count', weight='bold', style='italic', size=12)      # y label
ax.set_facecolor('slategray')             # background color
for label in ax.get_xticklabels(): label.set_weight('bold')     # x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')     # y-axis tick labels
plt.show()

# %%
# Plot: Number of customers by age (as % of total)
from matplotlib.ticker import FuncFormatter     # import necessary library used to add percent sign to tick labels
def to_percent(tick_value, position):    # define formatting function which takes the value of each tick as an arg
    s = str(int(tick_value))    # converts tick_value to sting...
    return s + '%'              # so it can be concatenated with "%"
age_counts = shopping['Age Range'].value_counts(normalize=True) * 100   # calculate the percentage of each age range category
age_percentage = age_counts.reset_index()   # convert the series to dataframe (with the two columns below) for plotting
age_percentage.columns = ['Age Range', 'Percentage']  
f, ax = plt.subplots(figsize=(10, 2))    # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.barplot(x="Age Range", y="Percentage", data=age_percentage, color='cyan', ax=ax)    # establish the plot
ax.set_title('Number of customers by age, as percentage of total', fontsize=14, weight='bold', style='italic', y=1)  # set overall plot title
ax.set_xlabel('Age Range', weight='bold', style='italic', size=12) # set x label
ax.set_ylabel('Percentage of Customers', weight='bold', style='italic', size=12) # set y label
ax.set_facecolor('slategray') # set background color
for label in ax.get_xticklabels(): label.set_weight('bold') # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold') # customize y-axis tick labels
formatter = FuncFormatter(to_percent)  # turns into formatter object so it can be passed to the axes
ax.yaxis.set_major_formatter(formatter)  # apply the formatting function 
plt.show() # show the plot

# %% [markdown]
# In looking solely at `Category`, it appears that the most common purchase is clothing, followed by accessories.

# %%
# plotting distribution across categories
category_order = shopping['Category'].value_counts().index  # create descending-order parameter 
f, ax = plt.subplots(figsize=(8, 4))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=shopping, color='springgreen', order=category_order, ax=ax)  # set up countplot
ax.set_title('Number of purchases by category', fontsize=14, weight='bold', style='italic', y=1)  # set overall plot title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # set x label
ax.set_ylabel('Purchase count', weight='bold', style='italic', size=12)  # set y label
ax.set_facecolor('slategray')  # set background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # make x-axis tick labels bold
for label in ax.get_yticklabels(): label.set_weight('bold')  # make y-axis tick labels bold 
plt.show()  # show the plot

# %%
# plotting distribution across categories as a percentage

# calculate the percentage of purchase count by each category
category_counts = shopping['Category'].value_counts(normalize=True) * 100

# convert the series to dataframe for plotting
category_percentage = category_counts.reset_index()
category_percentage.columns = ['Category', 'Percentage']

# set up plot and styles
f, ax = plt.subplots(figsize=(8, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.barplot(y="Category", x="Percentage", data=category_percentage, color='springgreen', ax=ax)

# set overall plot title
ax.set_title('Number of purchases by category, as a percentage', fontsize=14, weight='bold', style='italic', y=1)

# set y label
ax.set_ylabel('Category', weight='bold', style='italic', size=12)
# set x label
ax.set_xlabel('Percentage of Purchases', weight='bold', style='italic', size=12)

# set background color
ax.set_facecolor('slategray')

# make x-axis tick labels bold
for label in ax.get_xticklabels():
    label.set_weight('bold')
# make y-axis tick labels bold
for label in ax.get_yticklabels():
    label.set_weight('bold')

formatter = FuncFormatter(to_percent)
ax.xaxis.set_major_formatter(formatter)

# show the plot
plt.show()

# %% [markdown]
# In looking solely at `Gender`, it appears that most shoppers are men.

# %%
# plotting distribution across genders:

# set up plot and styles
f, ax = plt.subplots(figsize=(8, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.countplot(x="Gender", data=shopping, color='lemonchiffon', ax=ax)

# set overall plot title
ax.set_title('Number of purchases by gender', fontsize=14, weight='bold', style='italic', y=1)

# set x label
ax.set_xlabel('Gender', weight='bold', style='italic', size=12)
# set y label
ax.set_ylabel('Purchase count', weight='bold', style='italic', size=12)

# set background color
ax.set_facecolor('slategray')

# make x-axis tick labels bold
for label in ax.get_xticklabels():
    label.set_weight('bold')
# make y-axis tick labels bold 
for label in ax.get_yticklabels():
    label.set_weight('bold')

# show the plot
plt.show()

# %%
# plotting distribution across genders as a percentage

# calculate the percentage of purchase count by each gender
gender_counts = shopping['Gender'].value_counts(normalize=True) * 100

# convert the series to dataframe for plotting
gender_percentage = gender_counts.reset_index()
gender_percentage.columns = ['Gender', 'Percentage']

# set up plot and styles
f, ax = plt.subplots(figsize=(8, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.barplot(y="Gender", x="Percentage", data=gender_percentage, color='lemonchiffon', ax=ax)

# set overall plot title
ax.set_title('Number of purchases by gender, as a percentage', fontsize=14, weight='bold', style='italic', y=1)

# set y label
ax.set_ylabel('Gender', weight='bold', style='italic', size=12)
# set x label
ax.set_xlabel('Percentage of Purchases', weight='bold', style='italic', size=12)

# set background color
ax.set_facecolor('slategray')

# make x-axis tick labels bold
for label in ax.get_xticklabels():
    label.set_weight('bold')
# make y-axis tick labels bold
for label in ax.get_yticklabels():
    label.set_weight('bold')

formatter = FuncFormatter(to_percent)
ax.xaxis.set_major_formatter(formatter)

# show the plot
plt.show()

# %%
# plotting distribution across item type:

# create descending-order parameter 
item_order = shopping['Item Purchased'].value_counts().index

# set up plot and styles
f, ax = plt.subplots(figsize=(12, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.countplot(x="Item Purchased", data=shopping, color='paleturquoise', order=item_order, ax=ax)

# set overall plot title
ax.set_title('Number of purchases by item', fontsize=14, weight='bold', style='italic', y=1)

# set x label
ax.set_xlabel('Item Purchased', weight='bold', style='italic', size=12)
# set y label
ax.set_ylabel('Purchase count', weight='bold', style='italic', size=12)

# customize the x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, weight='bold')

# bolden the y-axis tick labels
for label in ax.get_yticklabels():
    label.set_weight('bold')

# set background color
ax.set_facecolor('slategray')

# show the plot
plt.show()

# %%
# plotting distribution across items purchased as a percentage

# calculate the percentage of purchase count by each gender
item_counts = shopping['Item Purchased'].value_counts(normalize=True) * 100

# convert the series to dataframe for plotting
item_percentage = item_counts.reset_index()
item_percentage.columns = ['Item Purchased', 'Percentage']

# set up plot and styles
f, ax = plt.subplots(figsize=(10, 6))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.barplot(y="Item Purchased", x="Percentage", data=item_percentage, color='paleturquoise', ax=ax)

# set overall plot title
ax.set_title('Number of purchases by item, as a percentage', fontsize=14, weight='bold', style='italic', y=1)

# set y label
ax.set_ylabel('Item Purchased', weight='bold', style='italic', size=12)
# set x label
ax.set_xlabel('Percentage of Purchases', weight='bold', style='italic', size=12)

# set background color
ax.set_facecolor('slategray')

# make x-axis tick labels bold
for label in ax.get_xticklabels():
    label.set_weight('bold')
# make y-axis tick labels bold
for label in ax.get_yticklabels():
    label.set_weight('bold')

formatter = FuncFormatter(to_percent)
ax.xaxis.set_major_formatter(formatter)

# show the plot
plt.show()

# %%
# plotting distribution of purchase amounts:

# set up plot and styles
f, ax = plt.subplots(figsize=(12, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.histplot(x="Purchase Amount (USD)", data=shopping, color='c', ax=ax)

# set overall plot title
ax.set_title('Distribution of Purchase Amount (USD)', fontsize=14, weight='bold', style='italic', y=1)

# set x label
ax.set_xlabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
# set y label
ax.set_ylabel(' ', weight='bold', style='italic', size=12)

# customize the x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, weight='bold')

# bolden the y-axis tick labels
for label in ax.get_yticklabels():
    label.set_weight('bold')

# set background color
ax.set_facecolor('slategray')

# show the plot
plt.show()
# Out:
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_72108/2135044264.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, weight='bold')

# %%
# plotting distribution of previous purchases:

# set up plot and styles
f, ax = plt.subplots(figsize=(12, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.histplot(x="Previous Purchases", data=shopping, color='plum', ax=ax)

# set overall plot title
ax.set_title('Distribution of Previous Purchases', fontsize=14, weight='bold', style='italic', y=1)

# set x label
ax.set_xlabel('Previous Purchases', weight='bold', style='italic', size=12)
# set y label
ax.set_ylabel(' ', weight='bold', style='italic', size=12)

# customize the x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, weight='bold')

# bolden the y-axis tick labels
for label in ax.get_yticklabels():
    label.set_weight('bold')

# set background color
ax.set_facecolor('slategray')

# show the plot
plt.show()
# Out:
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_72108/3138677034.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, weight='bold')

# %%
# plotting distribution of previous purchases, as a percentage

# calculate the percentage of previous purchases
previous_counts = shopping['Item Purchased'].value_counts(normalize=True) * 100

# convert the series to dataframe for plotting
previous_percentage = previous_counts.reset_index()
previous_percentage.columns = ['Item Purchased', 'Percentage']

# set up plot and styles
f, ax = plt.subplots(figsize=(8, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.barplot(y="Item Purchased", x="Percentage", data=item_percentage, color='paleturquoise', ax=ax)

# set overall plot title
ax.set_title('Number of purchases by item, as a percentage', fontsize=14, weight='bold', style='italic', y=1)

# set y label
ax.set_ylabel('Item Purchased', weight='bold', style='italic', size=12)
# set x label
ax.set_xlabel('Percentage of Purchases', weight='bold', style='italic', size=12)

# set background color
ax.set_facecolor('slategray')

# make x-axis tick labels bold
for label in ax.get_xticklabels():
    label.set_weight('bold')
# make y-axis tick labels bold
for label in ax.get_yticklabels():
    label.set_weight('bold')

formatter = FuncFormatter(to_percent)
ax.xaxis.set_major_formatter(formatter)

# show the plot
plt.show()

# %% [markdown]
# Looking at the most-commonly shopped categories for men and women, although it is reflected that the overall count of women shoppers is lower, the categories they shop are similar to men.

# %%
# plotting categories by gender:  

# create a filtered dataframe for male customers
male = shopping.query("Gender == 'Male'")
# create a filtered dataframe for female customers
female = shopping.query("Gender == 'Female'")

# create descending-order parameter for males
category_order_male = male['Category'].value_counts().index
# create descending-order parameter for females
category_order_female = female['Category'].value_counts().index

# set up plot and styles
f, ax = plt.subplots(2, 1, figsize=(8, 9))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot
sns.countplot(x="Category", data=male, color='darkturquoise', order=category_order_male, ax=ax[0])
# set overall plot title
ax[0].set_title('Most common purchase categories for males', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[0].set_xlabel('Category', weight='bold', style='italic', size=12)
# set y label
ax[0].set_ylabel('Purchase count', weight='bold', style='italic', size=12)
# bolden the x-axis tick labels
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
# customize the y-axis tick labels
ax[0].set_yticklabels(ax[0].get_yticklabels(), weight='bold')
# set background color
ax[0].set_facecolor('slategray')

# establish the plot
sns.countplot(x="Category", data=female, color='plum', order=category_order_female, ax=ax[1])
# set overall plot title
ax[1].set_title('Most common purchase categories for females', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[1].set_xlabel('Category', weight='bold', style='italic', size=12)
# set y label
ax[1].set_ylabel('Purchase Count', weight='bold', style='italic', size=12)
# bolden the x-axis tick labels
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
# customize the y-axis tick labels
ax[1].set_yticklabels(ax[1].get_yticklabels(), weight='bold')
# set background color
ax[1].set_facecolor('slategray')
# change x-axis limits so it matches the other plot
ax[1].set_ylim(0, 1200)

# show the plot
plt.show()
# Out:
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_72108/2940975779.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(ax[0].get_yticklabels(), weight='bold')
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_72108/2940975779.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels(ax[1].get_yticklabels(), weight='bold')

# %% [markdown]
# Looking at the most-commonly shopped items for men and women, we see that men appear to be purchasing

# %%
# plotting item types by categories by gender:  

male_clothing = male.query("Category == 'Clothing'")
male_accessories = male.query("Category == 'Accessories'")
male_footwear = male.query("Category == 'Footwear'")
male_outerwear = male.query("Category == 'Outerwear'")

female_clothing = female.query("Category == 'Clothing'")
female_accessories = female.query("Category == 'Accessories'")
female_footwear = female.query("Category == 'Footwear'")
female_outerwear = female.query("Category == 'Outerwear'")

# create descending-order parameter for males
item_order_male = male['Item Purchased'].value_counts().index
# create descending-order parameter for females
item_order_female = female['Item Purchased'].value_counts().index

# set up plot and styles
f, ax = plt.subplots(2, 4, figsize=(12, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# ----------------------------------------------------------------------------------------------------------------
# plot for clothing for males
sns.countplot(y="Item Purchased", data=male_clothing, color='darkturquoise', ax=ax[0,0])
# set overall plot title
ax[0,0].set_title('Clothing', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[0,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[0,0].set_ylabel('Item Purchased (Males)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[0,0].get_xticklabels() + ax[0,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[0,0].set_facecolor('slategray')

# plot for clothing for females 
sns.countplot(y="Item Purchased", data=female_clothing, color='plum', ax=ax[1,0])
# set overall plot title
ax[1,0].set_title('', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[1,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[1,0].set_ylabel('Item Purchased (Females)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[1,0].get_xticklabels() + ax[1,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[1,0].set_facecolor('slategray')
# ----------------------------------------------------------------------------------------------------------------
# plot for accessories for males
sns.countplot(y="Item Purchased", data=male_accessories, color='darkturquoise', ax=ax[0,0])
# set overall plot title
ax[1,1].set_title('Accessories', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[1,1].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[1,1].set_ylabel('Item Purchased (Males)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[1,1].get_xticklabels() + ax[0,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[0,0].set_facecolor('slategray')

# plot for accessories for females
sns.countplot(y="Item Purchased", data=female_accessories, color='plum', ax=ax[1,0])
# set overall plot title
ax[1,0].set_title('', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[1,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[1,0].set_ylabel('Item Purchased (Females)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[1,0].get_xticklabels() + ax[1,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[1,0].set_facecolor('slategray')
# ----------------------------------------------------------------------------------------------------------------
# plot for footwear for males 
sns.countplot(y="Item Purchased", data=male_footwear, color='darkturquoise', ax=ax[0,0])
# set overall plot title
ax[0,0].set_title('Footwear', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[0,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[0,0].set_ylabel('Item Purchased (Males)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[0,0].get_xticklabels() + ax[0,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[0,0].set_facecolor('slategray')

# plot for footwear for females 
sns.countplot(y="Item Purchased", data=female_footwear, color='plum', ax=ax[1,0])
# set overall plot title
ax[1,0].set_title('', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[1,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[1,0].set_ylabel('Item Purchased (Females)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[1,0].get_xticklabels() + ax[1,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[1,0].set_facecolor('slategray')
# ----------------------------------------------------------------------------------------------------------------
# plot for outerwear for males 
sns.countplot(y="Item Purchased", data=male_outerwear, color='darkturquoise', ax=ax[0,0])
# set overall plot title
ax[0,0].set_title('Outerwear', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[0,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[0,0].set_ylabel('Item Purchased (Males)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[0,0].get_xticklabels() + ax[0,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[0,0].set_facecolor('slategray')

# plot for outerwear for females 
sns.countplot(y="Item Purchased", data=female_outerwear, color='plum', ax=ax[1,0])
# set overall plot title
ax[1,0].set_title('', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax[1,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
# set y label
ax[1,0].set_ylabel('Item Purchased (Females)', weight='bold', style='italic', size=12)
# bolden both axes' tick labels
for label in ax[1,0].get_xticklabels() + ax[1,0].get_yticklabels():
    label.set_weight('bold')
# set background color
ax[1,0].set_facecolor('slategray')

# show the plot
plt.show()

# %%
# plotting item types by categories by gender:  

male_clothing = male.query("Category == 'Clothing'")
male_accessories = male.query("Category == 'Accessories'")
male_footwear = male.query("Category == 'Footwear'")
male_outerwear = male.query("Category == 'Outerwear'")

female_clothing = female.query("Category == 'Clothing'")
female_accessories = female.query("Category == 'Accessories'")
female_footwear = female.query("Category == 'Footwear'")
female_outerwear = female.query("Category == 'Outerwear'")

# create descending-order parameter for males
item_order_male = male['Item Purchased'].value_counts().index
# create descending-order parameter for females
item_order_female = female['Item Purchased'].value_counts().index

# set up plot and styles
f, ax = plt.subplots(2, 4, figsize=(20, 10))  # Adjusted for better aspect ratio if needed
plt.subplots_adjust(hspace=0.4, wspace=0.4)  # Adjusted spacing to avoid label overlap
sns.set_style('white')

# ----------------------------------------------------------------------------------------------------------------
# plot for clothing for males
sns.countplot(y="Item Purchased", data=male_clothing, color='darkturquoise', ax=ax[0,0])
ax[0,0].set_title('Male Clothing', fontsize=14, weight='bold', style='italic', y=1.02)
ax[0,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[0,0].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[0,0].set_facecolor('slategray')

# plot for clothing for females 
sns.countplot(y="Item Purchased", data=female_clothing, color='plum', ax=ax[1,0])
ax[1,0].set_title('Female Clothing', fontsize=14, weight='bold', style='italic', y=1.02)
ax[1,0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[1,0].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[1,0].set_facecolor('slategray')

# ----------------------------------------------------------------------------------------------------------------
# plot for accessories for males
sns.countplot(y="Item Purchased", data=male_accessories, color='darkturquoise', ax=ax[0,1])
ax[0,1].set_title('Male Accessories', fontsize=14, weight='bold', style='italic', y=1.02)
ax[0,1].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[0,1].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[0,1].set_facecolor('slategray')

# plot for accessories for females
sns.countplot(y="Item Purchased", data=female_accessories, color='plum', ax=ax[1,1])
ax[1,1].set_title('Female Accessories', fontsize=14, weight='bold', style='italic', y=1.02)
ax[1,1].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[1,1].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[1,1].set_facecolor('slategray')

# ----------------------------------------------------------------------------------------------------------------
# plot for footwear for males 
sns.countplot(y="Item Purchased", data=male_footwear, color='darkturquoise', ax=ax[0,2])
ax[0,2].set_title('Male Footwear', fontsize=14, weight='bold', style='italic', y=1.02)
ax[0,2].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[0,2].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[0,2].set_facecolor('slategray')

# plot for footwear for females 
sns.countplot(y="Item Purchased", data=female_footwear, color='plum', ax=ax[1,2])
ax[1,2].set_title('Female Footwear', fontsize=14, weight='bold', style='italic', y=1.02)
ax[1,2].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[1,2].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[1,2].set_facecolor('slategray')

# ----------------------------------------------------------------------------------------------------------------
# plot for outerwear for males 
sns.countplot(y="Item Purchased", data=male_outerwear, color='darkturquoise', ax=ax[0,3])
ax[0,3].set_title('Male Outerwear', fontsize=14, weight='bold', style='italic', y=1.02)
ax[0,3].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[0,3].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[0,3].set_facecolor('slategray')

# plot for outerwear for females 
sns.countplot(y="Item Purchased", data=female_outerwear, color='plum', ax=ax[1,3])
ax[1,3].set_title('Female Outerwear', fontsize=14, weight='bold', style='italic', y=1.02)
ax[1,3].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[1,3].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[1,3].set_facecolor('slategray')

# ----------------------------------------------------------------------------------------------------------------
plt.show()

# %%
# plotting categories by gender:  

# create descending-order parameter for males
item_order_male = male['Item Purchased'].value_counts().index
# create descending-order parameter for females
item_order_female = female['Item Purchased'].value_counts().index

# set up plot and styles
f, ax = plt.subplots(figsize=(12, 6))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# establish the plot for males
sns.countplot(x="Item Purchased", data=male, color='darkturquoise', order=item_order_male, ax=ax)

# establish the plot for females
sns.countplot(x="Item Purchased", data=female, color='plum', order=item_order_female, ax=ax)

# set overall plot title
ax.set_title('Most commonly purchased items for males', fontsize=14, weight='bold', style='italic', y=1)
# set x label
ax.set_xlabel('Item Purchased', weight='bold', style='italic', size=12)
# set y label
ax.set_ylabel('Purchase count', weight='bold', style='italic', size=12)
# customize the x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, weight='bold')
# bolden both axes' tick labels
for label in ax.get_yticklabels():
    label.set_weight('bold')
# set background color
ax.set_facecolor('slategray')



# show the plot
plt.show()

# %% [markdown]
# The median and range amount spent by each gender appears to be the same. Combining this with the earlier observation that men appear in greater numbers as customers, we can state a hypothesis that while there are more male shoppers, each individual shopper spends the same amount, on average, as the female customers.

# %%
# plotting distribution of purchase amounts across genders:

f, ax = plt.subplots(figsize=(6, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.boxplot(x="Gender", y='Purchase Amount (USD)', data=shopping, color='cyan', ax=ax)
ax.set_title('Amount spent (USD) by gender', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Gender', weight='bold', style='italic', size=12)
ax.set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax.set_facecolor('white')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting distribution of purchase amounts across genders:

f, ax = plt.subplots(2, 1, figsize=(6, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.histplot(x='Purchase Amount (USD)', data=male, color='darkturquoise', ax=ax[0])
ax[0].set_title('Amount spent (USD) by gender', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')

sns.histplot(x='Purchase Amount (USD)', data=female, color='plum', ax=ax[1])
ax[1].set_title('Amount spent (USD) by gender', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %% [markdown]
# The median amount of previous purchases for men is slightly higher than women, but their ranges are about the same. We can state a hypothesis that return customers are slightly more likely to be male than female.

# %%
# plotting distribution of previous purchases across genders:

f, ax = plt.subplots(figsize=(6, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.boxplot(x='Previous Purchases', y="Gender", data=shopping, color='cyan', ax=ax)
ax.set_title('Previous purchases, by gender', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Number of previous purchases', weight='bold', style='italic', size=12)
ax.set_ylabel('Gender', weight='bold', style='italic', size=12)
ax.set_facecolor('white')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %% [markdown]
# The median amount spent varies only slightly among the different age groups; the highest of all appearing to be the '51-55' range. The ranges are nearly identical. We could hypothesize that the '51-55' age range spends slightly more on average.

# %%
# plotting distribution of amounts spent across age ranges:

f, ax = plt.subplots(figsize=(7, 2))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.boxplot(x="Age Range", y='Purchase Amount (USD)', data=shopping, color='lemonchiffon', ax=ax)
ax.set_title('Amount spent (USD) by age range', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Age Range', weight='bold', style='italic', size=12)
ax.set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax.set_facecolor('white')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
ax.set_ylim(0, 120)
plt.show()

# %%
import plotly.express as px

df = px.data.tips()
fig = px.box(shopping, x="Age Range", y="Purchase Amount (USD)")
fig.show()

# %% [markdown]
# We can see that the previous purchase amounts are very similar by age range, with nearly identical ranges. Slight upwards movement could be hypothesized as age increases.

# %%
# plotting distribution of previous purchases across age ranges:

f, ax = plt.subplots(figsize=(10, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.boxplot(x="Age Range", y='Previous Purchases', data=shopping, color='lemonchiffon', ax=ax)
ax.set_title('Previous purchases, by age range', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Age Range', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of previous purchases', weight='bold', style='italic', size=12)
ax.set_facecolor('white')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %% [markdown]
# When broken down futher by gender, we can see further differences in variation across different age ranges. Variation across age ranges in men are slightly more stable, while for women there appears to be slightly more variation across groups (perhaps the fewer number of women shoppers overall contributes to this?).

# %%
# plotting distribution of amounts spent across age ranges:

f, ax = plt.subplots(2, 1, figsize=(10, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.boxplot(x="Age Range", y='Purchase Amount (USD)', data=male, color='darkturquoise', ax=ax[0])
ax[0].set_title('Amount spent (USD) by age range', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Age Range', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.boxplot(x="Age Range", y='Purchase Amount (USD)', data=female, color='plum', ax=ax[1])
ax[1].set_title('Amount spent (USD) by age range', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Age Range', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting counts of shipping type:

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Shipping Type", data=shopping, color='papayawhip', ax=ax)
ax.set_title('Customer count by shipping type', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Shipping Type', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting amount spent by shipping type:

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.barplot(x="Shipping Type", y='Purchase Amount (USD)', data=shopping, color='papayawhip', ax=ax)
ax.set_title('Amount spent (USD) by shipping type', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Shipping type', weight='bold', style='italic', size=12)
ax.set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting previous visits by shipping type:

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.barplot(x="Shipping Type", y='Previous Purchases', data=shopping, color='papayawhip', ax=ax)
ax.set_title('Return visitors by shipping type', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Shipping type', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of previous purchases', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting subscription status count:

f, ax = plt.subplots(figsize=(8, 6))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
countplot = sns.countplot(x="Subscription Status", data=shopping, color='papayawhip', ax=ax)
ax.set_title('Subscriber Count', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Subscription Status', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
# Add count labels above the bars
for p in countplot.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), '%d' % int(p.get_height()),
            fontsize=12, weight='bold', color='white', ha='center', va='bottom')

for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting gender makeup of subscribers vs non-subscribers:

male_subs = 
female_subs = 

f, ax = plt.subplots(2, 1, figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Subscription Status", data=shopping, color='papayawhip', ax=ax)
ax.set_title('Subscriber Count', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Subscription Status', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()
# Out:
#   Cell In[36], line 3
#     male_subs =
#                 ^
# SyntaxError: invalid syntax

# %%
# plotting gender makeup of subscribers vs non-subscribers:

f, ax = plt.subplots(1, 2, figsize=(8, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Subscription Status", data=male, color='darkturquoise', ax=ax[0])
ax[0].set_title('Male Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Subscription Status', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(x="Subscription Status", data=female, color='plum', ax=ax[1])
ax[1].set_title('Female Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Subscription Status', weight='bold', style='italic', size=12)
ax[1].set_ylabel('', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting gender makeup of subscribers vs non-subscribers:

f, ax = plt.subplots(1, 2, figsize=(10, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Subscription Status", data=male, color='darkturquoise', ax=ax[0])
ax[0].set_title('Male Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Age Range', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(x="Subscription Status", data=female, color='plum', ax=ax[1])
ax[1].set_title('Female Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Age Range', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Purchase Amount (USD)', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting purchase frequency of subscribers vs non-subscribers:

subs = shopping.query("`Subscription Status` == 'Yes'")
not_subs = shopping.query("`Subscription Status` == 'No'")

sub_order = ['Weekly', 'Bi-Weekly', 'Fortnightly', 'Monthly', 'Every 3 Months', 'Quarterly', 'Annually']

f, ax = plt.subplots(1, 2, figsize=(10, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Frequency of Purchases", data=subs, color='deepskyblue', order=sub_order, ax=ax[0])
ax[0].set_title('Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Purchase Frequency', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(y="Frequency of Purchases", data=not_subs, color='lightcoral', order=sub_order, ax=ax[1])
ax[1].set_title('Non-Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Purchase Frequency', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting purchase frequency of subscribers vs non-subscribers:

subs = shopping.query("`Subscription Status` == 'Yes'")
not_subs = shopping.query("`Subscription Status` == 'No'")

f, ax = plt.subplots(1, 2, figsize=(10, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Gender", data=subs, color='deepskyblue', ax=ax[0])
ax[0].set_title('Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(x="Gender", data=not_subs, color='lightcoral', ax=ax[1])
ax[1].set_title('Non-Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting purchase frequency of subscribers vs non-subscribers:

f, ax = plt.subplots(1, 2, figsize=(10, 4))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Age Range", data=subs, color='darkturquoise', ax=ax[0])
ax[0].set_title('Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Count', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(y="Age Range", data=not_subs, color='plum', ax=ax[1])
ax[1].set_title('Non-Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Count', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting purchase frequency of subscribers vs non-subscribers:

youngest = shopping.query("`Age Range` == '18-25'")

f, ax = plt.subplots(1, 2, figsize=(8, 2))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Gender", data=youngest, color='deepskyblue', ax=ax[0])
ax[0].set_title('Genders of youngest customers (age 18-25)', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(x="Subscription Status", data=youngest, color='plum', ax=ax[1])
ax[1].set_title('Non-Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Count', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting gender makeup of review rating

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Review Rating", data=shopping, color='pink', ax=ax)
ax.set_title('Counts by rating', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Review Rating', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting gender makeup of review rating

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.barplot(x="Review Rating", y='Purchase Amount (USD)', data=shopping, color='pink', ax=ax)
ax.set_title('Counts by rating', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Review Rating', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting gender makeup of review rating

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.barplot(x='Subscription Status', y="Review Rating", data=shopping, color='pink', ax=ax)
ax.set_title('Counts by rating', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Review Rating', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting gender makeup of review rating

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.barplot(x='', y="Review Rating", data=shopping, color='pink', ax=ax)
ax.set_title('Counts by rating', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Review Rating', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb Cell 72 line 6
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb#Y143sZmlsZQ%3D%3D?line=3'>4</a> plt.subplots_adjust(hspace=0.3, wspace=0.5)
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb#Y143sZmlsZQ%3D%3D?line=4'>5</a> sns.set_style('white')
# ----> <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb#Y143sZmlsZQ%3D%3D?line=5'>6</a> sns.barplot(x='', y="Review Rating", data=shopping, color='pink', ax=ax)
# ...

# %%
# plotting what categories are shopped by younger subscribers (all of whom are male)

sub_cats = shopping.query("`Subscription Status` == 'Yes' & `Age Range` == '18-25'")

f, ax = plt.subplots(figsize=(8, 5))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x='Category', data=sub_cats, color='lightblue', ax=ax)
ax.set_title('Counts by rating', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Review Rating', weight='bold', style='italic', size=12)
ax.set_ylabel('Number of customers', weight='bold', style='italic', size=12)
ax.set_facecolor('slategray')
for label in ax.get_xticklabels():
    label.set_weight('bold')
for label in ax.get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting most common categories and item types for youngest subscribers (all of whom are male)

f, ax = plt.subplots(1, 2, figsize=(10, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Category", data=sub_cats, color='lightblue', ax=ax[0])
ax[0].set_title('By Category', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(y="Item Purchased", data=sub_cats, color='lightblue', ax=ax[1])
ax[1].set_title('By Item', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Count', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting the purchase amounts for the youngest subscribers (all of whom are male) versus whole population

f, ax = plt.subplots(1, 2, figsize=(10, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.boxplot(x='', y="Purchase Amount (USD)", data=subs, color='lightblue', ax=ax[0])
ax[0].set_title('Subscribers', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(x="Purchase Amount (USD)", data=shopping, color='lightblue', ax=ax[1])
ax[1].set_title('All shoppers', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Count', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting most common categories and item types for subscribers (all of whom are male)

f, ax = plt.subplots(1, 2, figsize=(10, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Category", data=subs, color='lightblue', ax=ax[0])
ax[0].set_title('By Category', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(y="Item Purchased", data=subs, color='lightblue', ax=ax[1])
ax[1].set_title('By Item', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Count', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting most common categories and item types for subscribers (all of whom are male)

f, ax = plt.subplots(1, 2, figsize=(10, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Category", data=not_subs, color='lightblue', ax=ax[0])
ax[0].set_title('By Category', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')

sns.countplot(y="Category", data=subs, color='pink', ax=ax[0])
ax[0].set_title('By Category', fontsize=14, weight='bold', style='italic', y=1)
ax[0].set_xlabel('Gender', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[0].set_facecolor('white')
for label in ax[0].get_xticklabels():
    label.set_weight('bold')
for label in ax[0].get_yticklabels():
    label.set_weight('bold')


sns.countplot(y="Item Purchased", data=not_subs, color='lightblue', ax=ax[1])
ax[1].set_title('By Item', fontsize=14, weight='bold', style='italic', y=1)
ax[1].set_xlabel('Count', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)
ax[1].set_facecolor('white')
for label in ax[1].get_xticklabels():
    label.set_weight('bold')
for label in ax[1].get_yticklabels():
    label.set_weight('bold')
plt.show()

# %%
# plotting item types by categories by gender:  

clothing = shopping.query("Category == 'Clothing'")
accessories = shopping.query("Category == 'Accessories'")
footwear = shopping.query("Category == 'Footwear'")
outerwear = shopping.query("Category == 'Outerwear'")

# create descending-order parameter for males
item_order_male = male['Item Purchased'].value_counts().index
# create descending-order parameter for females
item_order_female = female['Item Purchased'].value_counts().index

# set up plot and styles
f, ax = plt.subplots(4,1, figsize=(10, 16))  # Adjusted for better aspect ratio if needed
plt.subplots_adjust(hspace=0.4, wspace=0.4)  # Adjusted spacing to avoid label overlap
sns.set_style('white')

# plot for clothing purchase amounts by age
sns.boxplot(x='Age Range', y="Purchase Amount (USD)", data=clothing, color='darkturquoise', ax=ax[0])
ax[0].set_title('Amount spent on clothing by age', fontsize=14, weight='bold', style='italic')
ax[0].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[0].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[0].set_facecolor('slategray')

# plot for accessory purchase amounts by age 
sns.boxplot(x="Age Range", y='Purchase Amount (USD)', data=accessories, color='plum', ax=ax[1])
ax[1].set_title('Amount spent on accessories by age', fontsize=14, weight='bold', style='italic')
ax[1].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[1].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[1].set_facecolor('slategray')

# plot for footwear purchase amounts by age
sns.boxplot(x="Age Range", y='Purchase Amount (USD)', data=footwear, color='darkturquoise', ax=ax[2])
ax[2].set_title('Amount spent on footwear by age', fontsize=14, weight='bold', style='italic')
ax[2].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[2].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[2].set_facecolor('slategray')

# plot for outerwear purchase amounts by age
sns.boxplot(x='Age Range', y="Purchase Amount (USD)", data=outerwear, color='plum', ax=ax[3])
ax[3].set_title('Amount spent on outerwear by age', fontsize=14, weight='bold', style='italic')
ax[3].set_xlabel('Purchase Count', weight='bold', style='italic', size=12)
ax[3].set_ylabel('Item Type', weight='bold', style='italic', size=12)
ax[3].set_facecolor('slategray')

plt.show()

# %%
import geopandas as gpd

haunted_places = pd.read_csv("Section_4_Data_Dives/DataDive2/haunted_places.csv")
# mapping states across data sets 

# import the JSON file containing states' boundaries
states_gdf = gpd.read_file('Section_4_Data_Dives/DataDive2/gz_2010_us_040_00_5m.json')

# initialize the plot
f, ax = plt.subplots(figsize=(18, 14))

# initialize the state boundary plot
states_gdf.boundary.plot(ax=ax, linewidth=1, color='black', facecolor='darkolivegreen', alpha=0.7, zorder=1)  

# set up a custom color palette using "flare" in reverse order for consistency
palette = sns.color_palette("flare_r", 3)

# define colors for each category
first_color = palette[0]
second_color = palette[1]
third_color = palette[2]

# highlight for the`spooky` states from client's preliminary research
top_spooky = spooky['state_no_spaces'].value_counts().head(18).index
highlight_gdf_top_spooky = states_gdf[states_gdf['NAME'].isin(top_spooky)]
highlight_gdf_top_spooky.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=first_color, zorder=2)
# highlight for the top `haunted places` states
top_haunted = haunted_places['state'].value_counts().head(25).index
highlight_gdf_top_haunted = states_gdf[states_gdf['NAME'].isin(top_haunted)]
highlight_gdf_top_haunted.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=second_color, zorder=3)
# highlight for states in both the `spooky` and the top `haunted places` datasets
both = top_spooky.intersection(top_haunted)
highlight_gdf_both = states_gdf[states_gdf['NAME'].isin(both)]
highlight_gdf_both.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=third_color, zorder=4)

# overall plot title
ax.set_title('Common Haunted States across Datasets', fontsize=20, weight='bold', style='italic')

# axis customization
ax.set_xlabel('Longitude', weight='bold', style='italic', size=12)
ax.set_ylabel('Latitude', weight='bold', style='italic', size=12)

# add a custom legend
legend_labels=['States only in Preliminary Data', 'States in Personal Accounts Data', 'States in Both Datasets']
legend_colors=[first_color, second_color, third_color]
legend_handles = [plt.Line2D([0], [0], marker='s', color='White', label=label, 
                             markersize=14, markerfacecolor=color, linestyle='None') 
                  for label, color in zip(legend_labels, legend_colors)]
legend = ax.legend(handles=legend_handles, title='Dataset contained in', fontsize='large', title_fontsize='x-large', labelspacing=0.9, borderpad=1, facecolor='white', loc='lower left')

# more legend modifications
legend.get_frame().set_boxstyle("square")
legend.get_frame().set_edgecolor('black') 
legend.get_frame().set_linewidth(1)

# set a background color
ax.set_facecolor('lightgrey')

# change axis limits so the US is centered
ax.set_ylim(22, 53)
ax.set_xlim(-126, -66)

# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb Cell 80 line 3
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb#Y161sZmlsZQ%3D%3D?line=0'>1</a> import geopandas as gpd
# ----> <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb#Y161sZmlsZQ%3D%3D?line=2'>3</a> haunted_places = pd.read_csv("Section_4_Data_Dives/DataDive2/haunted_places.csv")
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case3/Data_Dive_3/DataDive3_DATA3500/shopping_trends.ipynb#Y161sZmlsZQ%3D%3D?line=3'>4</a> # mapping states across data sets
# ...

# %%
# Plots: Most-shopped categories for customers aged 25+ years old and broken down by gender
rest = shopping.query("`Age Range` != '18-25'")  # create filter to filter out 18-25 age range
f, ax = plt.subplots(figsize=(10, 2))  # set up figure and styles 
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=rest, hue='Gender', palette='OrRd', ax=ax)  # set up countplot
ax.set_title('Most-shopped categories: customers 25+ years old, by gender', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('white')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
plt.show()  # show the plot

# %%
# Plots: Most-shopped items within each category, for customers aged 25+ years old and broken down by gender
rest_clothing = rest.query("Category == 'Clothing'")
rest_accessories = rest.query("Category == 'Accessories'")
rest_footwear = rest.query("Category == 'Footwear'")
rest_outerwear = rest.query("Category == 'Outerwear'")

f, ax = plt.subplots(2, 2, figsize=(12, 7))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=rest_clothing, hue='Gender', palette='OrRd', ax=ax[0,0])  # set up the countplot for clothing
ax[0,0].set_title('Top clothing items purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the clothing plot's title
ax[0,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's x-axis label
ax[0,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's y-axis label
ax[0,0].set_facecolor('white')  # clothing plot's background color
for label in ax[0,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's y-axis tick labels
ax[0,0].legend_.remove()  # remove clothing plot's legend

sns.countplot(y="Item Purchased", data=rest_accessories, hue='Gender', palette='OrRd', ax=ax[0,1])  # set up the countplot for accessories
ax[0,1].set_title('Top accessories purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the accessories' plot's title
ax[0,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's x-axis label
ax[0,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's y-axis label
ax[0,1].set_facecolor('white')  # accessories' plot's background color
for label in ax[0,1].get_xticklabels(): label.set_weight('bold')  # set up the accessories plot's x-axis tick labels
for label in ax[0,1].get_yticklabels(): label.set_weight('bold')  # set up the accessories plot's y-axis tick labels
ax[0,1].legend_.remove()  # remove accessories' plot's legend

sns.countplot(y="Item Purchased", data=rest_footwear, hue='Gender', palette='OrRd', ax=ax[1,0])  # set up the countplot for footwear
ax[1,0].set_title('Top accessories purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the footwear plot's title
ax[1,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's x-axis label
ax[1,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's y-axis label
ax[1,0].set_facecolor('white')  # footwear plot's background color
for label in ax[1,0].get_xticklabels(): label.set_weight('bold')  # set up the footwear plot's x-axis tick labels
for label in ax[1,0].get_yticklabels(): label.set_weight('bold')  # set up the footwear plot's y-axis tick labels
ax[1,0].legend_.remove()  # remove footwear plot's legend

sns.countplot(y="Item Purchased", data=rest_outerwear, hue='Gender', palette='OrRd', ax=ax[1,1])  # set up the countplot for outerwear
ax[1,1].set_title('Top outerwear purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the outerwear plot's title
ax[1,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's x-axis label
ax[1,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's y-axis label
ax[1,1].set_facecolor('white')  # outerwear plot's background color
for label in ax[1,1].get_xticklabels(): label.set_weight('bold')  # set up the outerwear plot's x-axis tick labels
for label in ax[1,1].get_yticklabels(): label.set_weight('bold')  # set up the outerwear plot's y-axis tick labels
ax[1,1].legend_.remove()  # remove outerwear plot's legend
plt.show()  # show the plot

# %%
# Plot: Most-shopped categories for customers aged 25+ years
rest = shopping.query("`Age Range` != '18-25'")  # set up a filter for shoppers who are above 25 years old
f, ax = plt.subplots(figsize=(10, 2))  # set up figure and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=rest, color='navy', ax=ax)  # set up countplot
ax.set_title('Most-shopped categories for customers 25+ years old', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('white')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
plt.show()  # show the plot

# %%
# Plots: Most-shopped items within each category, for customers aged 25+ years old
rest_clothing = rest.query("Category == 'Clothing'")
rest_accessories = rest.query("Category == 'Accessories'")
rest_footwear = rest.query("Category == 'Footwear'")
rest_outerwear = rest.query("Category == 'Outerwear'")

f, ax = plt.subplots(2, 2, figsize=(12, 7))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=rest_clothing, color='navy', ax=ax[0,0])  # set up the countplot for clothing
ax[0,0].set_title('Top clothing items purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the clothing plot's title
ax[0,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's x-axis label
ax[0,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's y-axis label
ax[0,0].set_facecolor('white')  # clothing plot's background color
for label in ax[0,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's y-axis tick labels

sns.countplot(y="Item Purchased", data=rest_accessories, color='navy', ax=ax[0,1])  # set up the countplot for accessories
ax[0,1].set_title('Top accessories purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the accessories' plot's title
ax[0,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's x-axis label
ax[0,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's y-axis label
ax[0,1].set_facecolor('white')  # accessories plot's background color
for label in ax[0,1].get_xticklabels(): label.set_weight('bold')  # set up the accessories plot's x-axis tick labels
for label in ax[0,1].get_yticklabels(): label.set_weight('bold')  # set up the accessories plot's y-axis tick labels

sns.countplot(y="Item Purchased", data=rest_footwear, color='navy', ax=ax[1,0])  # set up the countplot for footwear
ax[1,0].set_title('Top accessories purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the footwear plot's title
ax[1,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's x-axis label
ax[1,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's y-axis label
ax[1,0].set_facecolor('white')  # footwear plot's background color
for label in ax[1,0].get_xticklabels(): label.set_weight('bold')  # set up the footwear plot's x-axis tick labels
for label in ax[1,0].get_yticklabels(): label.set_weight('bold')  # set up the footwear plot's y-axis tick labels

sns.countplot(y="Item Purchased", data=rest_outerwear, color='navy', ax=ax[1,1])  # set up the countplot for outerwear
ax[1,1].set_title('Top outerwear purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the outerwear plot's title
ax[1,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's x-axis label
ax[1,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's y-axis label
ax[1,1].set_facecolor('white')  # outerwear plot's background color
for label in ax[1,1].get_xticklabels(): label.set_weight('bold')  # set up the outerwear plot's x-axis tick labels
for label in ax[1,1].get_yticklabels(): label.set_weight('bold')  # set up the outerwear plot's y-axis tick labels
plt.show()  # show the plot

# %%
# Plot: Most-shopped categories for customers aged 18-25 years
youngest = shopping.query("`Age Range` == '18-25'")  # create filter for the youngest age range
youngest_order = youngest['Category'].value_counts().index  # create a descending-order parameter
f, ax = plt.subplots(figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=youngest, color='powderblue', edgecolor='black', ax=ax, order=youngest_order)  # set up the countplot
ax.set_title('Most-shopped categories for all customers aged 18-25 years old', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('slategray')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
plt.show()  # show the plot

# %%
# Assuming 'Category' is your x-axis categorical variable:
categories = youngest['Category'].value_counts().index.tolist()

# Set your default color and the highlight color
default_color = 'powderblue'
highlight_color = 'tomato'  # Choose a color that will stand out
highlighted_category = 'Clothing'  # Replace with the category you want to highlight

# Create a list of colors
colors = [highlight_color if category == highlighted_category else default_color for category in categories]

# Plot: Most-shopped categories for customers aged 18-25 years
youngest = shopping.query("`Age Range` == '18-25'")  # create filter for the youngest age range
f, ax = plt.subplots(figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=youngest, palette=colors, edgecolor='black', ax=ax, order=categories)  # set up the countplot
ax.set_title('Most-shopped categories for all customers aged 18-25 years old', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('slategray')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
plt.show()  # show the plot

# %%
# Assuming 'Category' is your x-axis categorical variable:
categories = youngest['Category'].value_counts().index.tolist()

# Set your default color and the highlight color
default_color = 'powderblue'
highlight_color = 'tomato'  # Choose a color that will stand out
highlighted_category = 'Clothing'  # Replace with the category you want to highlight

# Create a list of colors
colors = [highlight_color if category == highlighted_category else default_color for category in categories]

# Plot: Most-shopped categories for customers aged 18-25 years
youngest = shopping.query("`Age Range` == '18-25'")  # create filter for the youngest age range
f, ax = plt.subplots(figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=youngest, palette=colors, edgecolor='black', ax=ax, order=categories)  # set up the countplot
ax.set_title('Most-shopped categories for all customers aged 18-25 years old', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('slategray')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
plt.show()  # show the plot

# %%
# Assuming 'Category' is your x-axis categorical variable:
clothing_items = youngest_clothing['Item Purchased'].value_counts().index.tolist()

# Set your default color and the highlight color
default_color = 'powderblue'
highlight_color = 'tomato'  # Choose a color that will stand out
highlighted_item = 'Shorts'  # Replace with the category you want to highlight

# Create a list of colors
colors = [highlight_color if item == highlighted_item else default_color for item in clothing_items]

# Plot: Most-shopped categories for customers aged 18-25 years
youngest = shopping.query("`Age Range` == '18-25'")  # create filter for the youngest age range
f, ax = plt.subplots(figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=youngest, palette=colors, edgecolor='black', ax=ax, order=clothing_items)  # set up the countplot
ax.set_title('Most-shopped categories for all customers aged 18-25 years old', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('slategray')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

plt.show()  # show the plot

# %%
# Assuming 'Category' is your x-axis categorical variable:
clothing_items = youngest_clothing['Item Purchased'].value_counts().index.tolist()

# Set your default color and the highlight color
default_color = 'powderblue'
highlight_color = 'tomato'  # Choose a color that will stand out
highlighted_item = 'Shorts'  # Replace with the category you want to highlight

# Create a list of colors
colors = [highlight_color if item == highlighted_item else default_color for item in clothing_items]

youngest_male = shopping.query("(`Age Range` == '18-25') & (Gender == 'Male')")  # create filter for the youngest age range
f, ax = plt.subplots(1, 2, figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

sns.countplot(y="Item Purchased", data=youngest_male, palette=colors, edgecolor='black', ax=ax[0], order=clothing_items)  # set up the countplot
ax[0].set_title('Male Customers', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[0].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[0].set_facecolor('slategray')  # set a background color
for label in ax[0].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[0].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels



# Assuming 'Category' is your x-axis categorical variable:
clothing_items = youngest_clothing['Item Purchased'].value_counts().index.tolist()

# Set your default color and the highlight color
default_color = 'powderblue'
highlight_color = 'tomato'  # Choose a color that will stand out
highlighted_item = 'Shorts'  # Replace with the category you want to highlight

# Create a list of colors
colors = [highlight_color if item == highlighted_item else default_color for item in clothing_items]

youngest_female = shopping.query("(`Age Range` == '18-25') & (Gender == 'Female')")  # create filter for the youngest age range

sns.countplot(y="Item Purchased", data=youngest_female, palette=colors, edgecolor='black', ax=ax[1], order=clothing_items)  # set up the countplot
ax[1].set_title('Female Customers', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[1].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[1].set_facecolor('slategray')  # set a background color
for label in ax[1].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[1].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

# %%
clothing_items = youngest_clothing['Item Purchased'].value_counts().index.tolist()  # items to iterate through
second_highest_range_clothing_items = second_highest_range_clothing['Item Purchased'].value_counts().index.tolist()

default_color = 'powderblue'    # default color the bars will display as
highlight_color = 'tomato'      # highlight color
highlighted_item = 'Shorts'     # item to highlight

youngest_colors = [highlight_color if item == highlighted_item else default_color for item in clothing_items]  # iterate and add to list
second_highest_range_colors = [highlight_color if item == highlighted_item else default_color for item in second_highest_range_clothing_items]

f, ax = plt.subplots(1, 2, figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

sns.countplot(y="Item Purchased", data=youngest, palette=colors, edgecolor='black', ax=ax[0], order=clothing_items)  # set up the countplot
ax[0].set_title('18-25 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[0].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[0].set_facecolor('slategray')  # set a background color
for label in ax[0].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[0].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

sns.countplot(y="Item Purchased", data=second_highest_range, palette=second_highest_range_colors, edgecolor='black', ax=ax[1], order=second_highest_range_clothing_items)  # set up the countplot
ax[1].set_title('51-60 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[1].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[1].set_facecolor('slategray')  # set a background color
for label in ax[1].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[1].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

# %%
accessories_items = youngest_accessories['Item Purchased'].value_counts().index.tolist()  # items to iterate through
second_highest_range_accessories_items = second_highest_range_accessories['Item Purchased'].value_counts().index.tolist()

default_color = 'powderblue'    # default color the bars will display as
highlight_color = 'tomato'      # highlight color
highlighted_item = 'Sunglasses'     # item to highlight

youngest_colors_accessories = [highlight_color if item == highlighted_item else default_color for item in accessories_items]  # iterate and add to list
second_highest_range_colors_accessories = [highlight_color if item == highlighted_item else default_color for item in second_highest_range_accessories_items]

f, ax = plt.subplots(1, 2, figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

sns.countplot(y="Item Purchased", data=youngest, palette=youngest_colors_accessories, edgecolor='black', ax=ax[0], order=accessories_items)  # set up the countplot
ax[0].set_title('18-25 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[0].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[0].set_facecolor('slategray')  # set a background color
for label in ax[0].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[0].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

sns.countplot(y="Item Purchased", data=second_highest_range, palette=second_highest_range_colors_accessories, edgecolor='black', ax=ax[1], order=second_highest_range_accessories_items)  # set up the countplot
ax[1].set_title('51-60 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[1].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[1].set_facecolor('slategray')  # set a background color
for label in ax[1].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[1].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

# %%
footwear_items = youngest_footwear['Item Purchased'].value_counts().index.tolist()  # items to iterate through
second_highest_range_footwear_items = second_highest_range_footwear['Item Purchased'].value_counts().index.tolist()

default_color = 'powderblue'    # default color the bars will display as
highlight_color = 'tomato'      # highlight color
highlighted_item = 'Sandals'     # item to highlight

youngest_colors_footwear = [highlight_color if item == highlighted_item else default_color for item in footwear_items]  # iterate and add to list
second_highest_range_colors_footwear = [highlight_color if item == highlighted_item else default_color for item in second_highest_range_footwear_items]

f, ax = plt.subplots(1, 2, figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

sns.countplot(y="Item Purchased", data=youngest, palette=youngest_colors_footwear, edgecolor='black', ax=ax[0], order=footwear_items)  # set up the countplot
ax[0].set_title('18-25 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[0].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[0].set_facecolor('slategray')  # set a background color
for label in ax[0].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[0].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

sns.countplot(y="Item Purchased", data=second_highest_range, palette=second_highest_range_colors_footwear, edgecolor='black', ax=ax[1], order=second_highest_range_footwear_items)  # set up the countplot
ax[1].set_title('51-60 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[1].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[1].set_facecolor('slategray')  # set a background color
for label in ax[1].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[1].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

# %%
outerwear_items = youngest_outerwear['Item Purchased'].value_counts().index.tolist()  # items to iterate through
second_highest_range_outerwear_items = second_highest_range_outerwear['Item Purchased'].value_counts().index.tolist()

default_color = 'powderblue'                         # default color the bars for the 18-25 year old range will display as
default_color_second_highest_range = 'steelblue'    # default color the bars for the 51-60 year old range will display as
highlight_color = 'tomato'                           # highlight color
highlighted_item = 'Jacket'                          # item to highlight

youngest_colors_outerwear = [highlight_color if item == highlighted_item else default_color for item in outerwear_items]  # iterate and add to list
second_highest_range_colors_outerwear = [highlight_color if item == highlighted_item else default_color_second_highest_range for item in second_highest_range_outerwear_items]

f, ax = plt.subplots(1, 2, figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

sns.countplot(y="Item Purchased", data=youngest, palette=youngest_colors_outerwear, edgecolor='black', ax=ax[0], order=outerwear_items)  # set up the countplot
ax[0].set_title('18-25 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[0].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[0].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[0].set_facecolor('slategray')  # set a background color
for label in ax[0].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[0].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

sns.countplot(y="Item Purchased", data=second_highest_range, palette=second_highest_range_colors_outerwear, edgecolor='black', ax=ax[1], order=second_highest_range_outerwear_items)  # set up the countplot
ax[1].set_title('51-60 Years', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax[1].set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax[1].set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax[1].set_facecolor('slategray')  # set a background color
for label in ax[1].get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax[1].get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels

# %%
# Plot: Most-shopped items within each category, for customers aged 18-25 years old
youngest_clothing = youngest.query("Category == 'Clothing'")  # create filter for each category for 18-25 age range
youngest_accessories = youngest.query("Category == 'Accessories'")
youngest_footwear = youngest.query("Category == 'Footwear'")
youngest_outerwear = youngest.query("Category == 'Outerwear'")

youngest_clothing_order = youngest_clothing['Item Purchased'].value_counts().index  # create order parameter for each category
youngest_accessories_order = youngest_accessories['Item Purchased'].value_counts().index
youngest_footwear_order = youngest_footwear['Item Purchased'].value_counts().index
youngest_outerwear_order = youngest_outerwear['Item Purchased'].value_counts().index

f, ax = plt.subplots(2, 2, figsize=(10, 6))  # set up the plots and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=youngest_clothing, color='lightblue', order=youngest_clothing_order, ax=ax[0,0])  # set up the countplot for clothing
ax[0,0].set_title('Top clothing items purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the clothing plot's title
ax[0,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's x-axis label
ax[0,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's y-axis label
ax[0,0].set_facecolor('white')  # clothing plot's background color
for label in ax[0,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's y-axis tick labels

sns.countplot(y="Item Purchased", data=youngest_accessories, color='lightblue', order=youngest_accessories_order,  ax=ax[0,1])  # set up the countplot for accessories
ax[0,1].set_title('Top accessories purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the accessories' plot's title
ax[0,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's x-axis label
ax[0,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's y-axis label
ax[0,1].set_facecolor('white')  # accessories' plot's background color
for label in ax[0,1].get_xticklabels(): label.set_weight('bold')  # set up the accessories' plot's x-axis tick labels
for label in ax[0,1].get_yticklabels(): label.set_weight('bold')  # set up the accessories' plot's y-axis tick labels

sns.countplot(y="Item Purchased", data=youngest_footwear, color='lightblue', order=youngest_footwear_order,  ax=ax[1,0])  # set up the countplot for footwear
ax[1,0].set_title('Top footwear purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the footwear plot's title
ax[1,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's x-axis label
ax[1,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's y-axis label
ax[1,0].set_facecolor('white')  # footwear plot's background color
for label in ax[1,0].get_xticklabels(): label.set_weight('bold')  # set up the footwear plot's x-axis tick labels
for label in ax[1,0].get_yticklabels(): label.set_weight('bold')  # set up the footwear plot's y-axis tick labels

sns.countplot(y="Item Purchased", data=youngest_outerwear, color='lightblue', order=youngest_outerwear_order,  ax=ax[1,1])  # set up the countplot for outerwear
ax[1,1].set_title('Top outerwear purchased', fontsize=14, weight='bold', style='italic', y=1)  # set up the outerwear plot's title
ax[1,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's x-axis label
ax[1,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's y-axis label
ax[1,1].set_facecolor('white')  # outerwear plot's background color
for label in ax[1,1].get_xticklabels(): label.set_weight('bold')  # set up the outerwear plot's x-axis tick labels
for label in ax[1,1].get_yticklabels(): label.set_weight('bold')  # set up the outerwear plot's y-axis tick labels
plt.show()  # show the plots

# %%
# Plot: Most-shopped categories customers aged 18-25 years old, broken down by gender
youngest_order = youngest['Category'].value_counts().index  # create a descending-order parameter
f, ax = plt.subplots(figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=youngest, hue='Gender', order=youngest_order, ax=ax)  # set up the countplot
ax.set_title('Most-shopped categories: customers aged 18-25 years old, by gender', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('white')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))  # customize the legend placement
plt.show()  # show the plot

# %%
# Plots: Most-shopped items within each category, for customers aged 18-25 years old and broken down by gender
youngest_clothing = youngest.query("Category == 'Clothing'")  # create filter for clothing category for 18-25 age range
youngest_accessories = youngest.query("Category == 'Accessories'")  # create filter for accessories category for 18-25 age range
youngest_footwear = youngest.query("Category == 'Footwear'")  # create filter for footwear category for 18-25 age range
youngest_outerwear = youngest.query("Category == 'Outerwear'")  # create filter for outerwear category for 18-25 age range

f, ax = plt.subplots(2, 2, figsize=(10, 6))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=youngest_clothing, hue='Gender', order=youngest_clothing_order, ax=ax[0,0])  # set up the countplot for clothing
ax[0,0].set_title('Clothing', fontsize=10, weight='bold', style='italic', y=1)  # set up the clothing plot's title
ax[0,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's x-axis label
ax[0,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's y-axis label
ax[0,0].set_facecolor('white')  # clothing plot's background color
#for label in ax[0,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's y-axis tick labels
ax[0,0].legend_.remove()  # remove clothing plot's legend

sns.countplot(y="Item Purchased", data=youngest_accessories, hue='Gender', order=youngest_accessories_order, ax=ax[0,1])  # set up the countplot for accessories
ax[0,1].set_title('Accessories', fontsize=10, weight='bold', style='italic', y=1)  # set up the accessories' plot's title
ax[0,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's x-axis label
ax[0,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's y-axis label
ax[0,1].set_facecolor('white')  # accessories' plot's background color
#for label in ax[0,1].get_xticklabels(): label.set_weight('bold')  # set up the accessories' plot's x-axis tick labels
for label in ax[0,1].get_yticklabels(): label.set_weight('bold')  # set up the accessories' plot's y-axis tick labels
ax[0,1].legend_.remove()  # remove accessories' plot's legend

sns.countplot(y="Item Purchased", data=youngest_footwear, hue='Gender', order=youngest_footwear_order, ax=ax[1,0])  # set up the countplot for footwear
ax[1,0].set_title('Footwear', fontsize=10, weight='bold', style='italic', y=1)  # set up the footwear plot's title
ax[1,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's x-axis label
ax[1,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's y-axis label
ax[1,0].set_facecolor('white')  # footwear plot's background color
#for label in ax[1,0].get_xticklabels(): label.set_weight('bold')  # set up the footwear plot's x-axis tick labels
for label in ax[1,0].get_yticklabels(): label.set_weight('bold')  # set up the footwear plot's y-axis tick labels
ax[1,0].legend_.remove()  # remove footwear plot's legend

sns.countplot(y="Item Purchased", data=youngest_outerwear, hue='Gender', order=youngest_outerwear_order, ax=ax[1,1])  # set up the countplot for outerwear
ax[1,1].set_title('Outerwear', fontsize=10, weight='bold', style='italic', y=1)  # set up the outerwear plot's title
ax[1,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's x-axis label
ax[1,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's y-axis label
ax[1,1].set_facecolor('white')  # outerwear plot's background color
#for label in ax[1,1].get_xticklabels(): label.set_weight('bold')  # set up the outerwear plot's x-axis tick labels
#for label in ax[1,1].get_yticklabels(): label.set_weight('bold')  # set up the outerwear plot's y-axis tick labels
ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(), size=8)  # set up the outerwear plot's x-axis tick labels
ax[1,1].set_yticklabels(ax[1,1].get_yticklabels(), weight='bold')  # set up the outerwear plot's y-axis tick labels
ax[1,1].legend_.remove()  # remove outerwear plot's legend
plt.show()  # show the plots
# Out:
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_72108/3052702564.py:44: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
# Plot: Most-shopped categories for customers aged 18-25 years
second_highest_range = shopping.query("`Age Range` == '51-55' | `Age Range` == '56-60'")  # set up a filter for the next-most frequent aged shoppers (51-55 age range)
second_highest_range_order = second_highest_range['Category'].value_counts().index  # create a descending-order parameter
f, ax = plt.subplots(figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=second_highest_range, color='steelblue', ax=ax, order=second_highest_range_order)  # set up the countplot
ax.set_title('Most-shopped categories for all customers aged 51-60 years old', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('white')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
plt.show()  # show the plot

# %%
# Plots: Most-shopped items within each category, for customers aged 51-55 years old
second_highest_range_clothing = second_highest_range.query("Category == 'Clothing'")  # create filter for each category for 51-55 age range
second_highest_range_accessories = second_highest_range.query("Category == 'Accessories'") 
second_highest_range_footwear = second_highest_range.query("Category == 'Footwear'") 
second_highest_range_outerwear = second_highest_range.query("Category == 'Outerwear'") 

second_highest_range_clothing_order = second_highest_range_clothing['Item Purchased'].value_counts().index  # create order parameter for each category
second_highest_range_accessories_order = second_highest_range_accessories['Item Purchased'].value_counts().index
second_highest_range_footwear_order = second_highest_range_footwear['Item Purchased'].value_counts().index
second_highest_range_outerwear_order = second_highest_range_outerwear['Item Purchased'].value_counts().index

f, ax = plt.subplots(2, 2, figsize=(10, 6))  # set up figure and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=second_highest_range_clothing, color='steelblue', order=second_highest_range_clothing_order, ax=ax[0,0])  # set up the countplot for clothing
ax[0,0].set_title('Clothing', fontsize=12, weight='bold', style='italic', y=1)  # set up the clothing plot's title
ax[0,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's x-axis label
ax[0,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's y-axis label
ax[0,0].set_facecolor('white')  # clothing plot's background color
#for label in ax[0,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's y-axis tick labels

sns.countplot(y="Item Purchased", data=second_highest_range_accessories, color='steelblue', order=second_highest_range_accessories_order, ax=ax[0,1])  # set up the countplot for accessories
ax[0,1].set_title('Accessories', fontsize=12, weight='bold', style='italic', y=1)  # set up the accessories' plot's title
ax[0,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's x-axis label
ax[0,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's y-axis label
ax[0,1].set_facecolor('white')  # accessories plot's background color
#for label in ax[0,1].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,1].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels

sns.countplot(y="Item Purchased", data=second_highest_range_footwear, color='steelblue', order=second_highest_range_footwear_order, ax=ax[1,0])  # set up the countplot for footwear
ax[1,0].set_title('Footwear', fontsize=12, weight='bold', style='italic', y=1)  # set up the footwear plot's title
ax[1,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's x-axis label
ax[1,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's y-axis label
ax[1,0].set_facecolor('white')  # footwear plot's background color
#for label in ax[1,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[1,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels

sns.countplot(y="Item Purchased", data=second_highest_range_outerwear, color='steelblue', order=second_highest_range_outerwear_order, ax=ax[1,1])  # set up the countplot for outerwear
ax[1,1].set_title('Outerwear', fontsize=12, weight='bold', style='italic', y=1)  # set up the outerwear plot's title
ax[1,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's x-axis label
ax[1,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's y-axis label
ax[1,1].set_facecolor('white')  # outerwear plot's background color
#for label in ax[1,1].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[1,1].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
plt.show()  # show the plot

# %%
# Plot: Most-shopped categories for customers aged 51-60 years old
second_highest_range = shopping.query("`Age Range` == '51-55' | `Age Range` == '56-60'")  # set up a filter for the next-most frequent aged shoppers (51-55 age range)
second_highest_range_order = second_highest_range['Category'].value_counts().index  # create a descending-order parameter
f, ax = plt.subplots(figsize=(10, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Category", data=second_highest_range, hue='Gender', palette='Greens', order=second_highest_range_order, ax=ax)
ax.set_title('Most-shopped categories: customers aged 51-60 years old, by gender', fontsize=14, weight='bold', style='italic', y=1)
ax.set_xlabel('Category', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('white')  # set a background color
for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))  # customize the legend placement
plt.show()  # show the plot

# %%
# Plots: Most-shopped items within each category, for customers aged 51-55 years old and broken down by gender
second_highest_range_clothing = second_highest_range.query("Category == 'Clothing'")  # create filter for clothing category for 51-55 age range
second_highest_range_accessories = second_highest_range.query("Category == 'Accessories'")  # create filter for accessories category for 51-55 age range
second_highest_range_footwear = second_highest_range.query("Category == 'Footwear'")  # create filter for footwear category for 51-55 age range
second_highest_range_outerwear = second_highest_range.query("Category == 'Outerwear'")  # create filter for outerwear category for 51-55 age range

f, ax = plt.subplots(2, 2, figsize=(10, 6))  # set up figure and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=second_highest_range_clothing, hue='Gender', palette='Greens', order=second_highest_range_clothing_order, ax=ax[0,0])  # set up the countplot for clothing
ax[0,0].set_title('Clothing', fontsize=12, weight='bold', style='italic', y=1)  # set up the clothing plot's title
ax[0,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's x-axis label
ax[0,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's y-axis label
ax[0,0].set_facecolor('white')  # clothing plot's background color
#for label in ax[0,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's y-axis tick labels
ax[0,0].legend_.remove()  # remove clothing plot's legend

sns.countplot(y="Item Purchased", data=second_highest_range_accessories, hue='Gender', palette='Greens', order=second_highest_range_accessories_order, ax=ax[0,1])  # set up the countplot for accessories
ax[0,1].set_title('Accessories', fontsize=12, weight='bold', style='italic', y=1)  # set up the accessories' plot's title
ax[0,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's x-axis label
ax[0,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the accessories' plot's y-axis label
ax[0,1].set_facecolor('white')  # accessories plot's background color
#for label in ax[0,1].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[0,1].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
ax[0,1].legend_.remove()  # remove accessories' plot's legend

sns.countplot(y="Item Purchased", data=second_highest_range_footwear, hue='Gender', palette='Greens', order=second_highest_range_footwear_order, ax=ax[1,0])  # set up the countplot for footwear
ax[1,0].set_title('Footwear', fontsize=12, weight='bold', style='italic', y=1)  # set up the footwear plot's title
ax[1,0].set_xlabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's x-axis label
ax[1,0].set_ylabel('', weight='bold', style='italic', size=12)  # customize the footwear plot's y-axis label
ax[1,0].set_facecolor('white')  # footwear plot's background color
#for label in ax[1,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[1,0].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
ax[1,0].legend_.remove()  # remove footwear plot's legend

sns.countplot(y="Item Purchased", data=second_highest_range_outerwear, hue='Gender', palette='Greens', order=second_highest_range_outerwear_order, ax=ax[1,1])  # set up the countplot for outerwear
ax[1,1].set_title('Outerwear', fontsize=12, weight='bold', style='italic', y=1)  # set up the outerwear plot's title
ax[1,1].set_xlabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's x-axis label
ax[1,1].set_ylabel('', weight='bold', style='italic', size=12)  # customize the outerwear plot's y-axis label
ax[1,1].set_facecolor('white')  # outerwear plot's background color
#for label in ax[1,1].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax[1,1].get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
ax[1,1].legend_.remove()  # remove outerwear plot's legend
plt.show()  # show the plot

# %%
# Plots: Most-shopped items within each category, for customers aged 18-25 years old and broken down by gender
youngest_clothing = youngest.query("Category == 'Clothing'")  # create filter for clothing category for 18-25 age range
youngest_accessories = youngest.query("Category == 'Accessories'")  # create filter for accessories category for 18-25 age range
youngest_footwear = youngest.query("Category == 'Footwear'")  # create filter for footwear category for 18-25 age range
youngest_outerwear = youngest.query("Category == 'Outerwear'")  # create filter for outerwear category for 18-25 age range

# Assuming 'Category' is your x-axis categorical variable:
clothing_items = youngest_clothing['Category'].value_counts().index.tolist()

# Set your default color and the highlight color
default_color = 'powderblue'
highlight_color = 'tomato'  # Choose a color that will stand out
highlighted_clothing_item = 'Shorts'  # Replace with the category you want to highlight

# Create a list of colors
clothing_colors = [highlight_color if item == highlighted_clothing_item else default_color for item in clothing_items]

f, ax = plt.subplots(figsize=(10, 6))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(y="Item Purchased", data=youngest_clothing, hue='Gender', palette=colors, order=youngest_clothing_order, ax=ax)  # set up the countplot for clothing
ax.set_title('Clothing', fontsize=10, weight='bold', style='italic', y=1)  # set up the clothing plot's title
ax.set_xlabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's x-axis label
ax.set_ylabel('', weight='bold', style='italic', size=12)  # customize the clothing plot's y-axis label
ax.set_facecolor('white')  # clothing plot's background color
#for label in ax[0,0].get_xticklabels(): label.set_weight('bold')  # set up the clothing plot's x-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # set up the clothing plot's y-axis tick labels
ax.legend_.remove()  # remove clothing plot's legend

plt.show()  # show the plots

# %%
import geopandas as gpd

# import the JSON file containing states' boundaries
states_gdf = gpd.read_file('gz_2010_us_040_00_5m.json')

# initialize the plot
f, ax = plt.subplots(figsize=(18, 14))

# initialize the state boundary plot
states_gdf.boundary.plot(ax=ax, linewidth=1, color='black', facecolor='darkolivegreen', alpha=0.7, zorder=1)  

# set up a custom color palette using "flare" in reverse order for consistency
palette = sns.color_palette("turbo", 5)

# define colors for each category
first_color = palette[0]
second_color = palette[1]
third_color = palette[2]
third_color = palette[3]
third_color = palette[4]

# highlight for the`spooky` states from client's preliminary research
top_five = shopping['Location'].value_counts().head(5).index
highlight_gdf_top = states_gdf[states_gdf['NAME'].isin(top_five)]
highlight_gdf_top.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=second_color, zorder=6)
# highlight for the top `haunted places` states
six_thru_ten = shopping['Location'].value_counts().head(10).index
highlight_gdf_six_thru_ten = states_gdf[states_gdf['NAME'].isin(six_thru_ten)]
highlight_gdf_six_thru_ten.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=third_color, zorder=5)
# highlight for the top `haunted places` states
six_thru_ten = shopping['Location'].value_counts().head(10).index
highlight_gdf_six_thru_ten = states_gdf[states_gdf['NAME'].isin(six_thru_ten)]
highlight_gdf_six_thru_ten.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=third_color, zorder=4)
# highlight for the top `haunted places` states
six_thru_ten = shopping['Location'].value_counts().head(10).index
highlight_gdf_six_thru_ten = states_gdf[states_gdf['NAME'].isin(six_thru_ten)]
highlight_gdf_six_thru_ten.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=third_color, zorder=3)
# highlight for the top `haunted places` states
six_thru_ten = shopping['Location'].value_counts().head(10).index
highlight_gdf_six_thru_ten = states_gdf[states_gdf['NAME'].isin(six_thru_ten)]
highlight_gdf_six_thru_ten.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=third_color, zorder=2)




#top_haunted = haunted_places['state'].value_counts().head(25).index
#highlight_gdf_top_haunted = states_gdf[states_gdf['NAME'].isin(top_haunted)]
#highlight_gdf_top_haunted.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=second_color, zorder=3)
# highlight for states in both the `spooky` and the top `haunted places` datasets
#both = top_spooky.intersection(top_haunted)
#highlight_gdf_both = states_gdf[states_gdf['NAME'].isin(both)]
#highlight_gdf_both.boundary.plot(ax=ax, linewidth=2, color='black', facecolor=third_color, zorder=4)

# overall plot title
ax.set_title('Common Haunted States across Datasets', fontsize=20, weight='bold', style='italic')

# axis customization
ax.set_xlabel('Longitude', weight='bold', style='italic', size=12)
ax.set_ylabel('Latitude', weight='bold', style='italic', size=12)

# add a custom legend
legend_labels=['States only in Preliminary Data', 'States in Personal Accounts Data', 'States in Both Datasets']
legend_colors=[first_color, second_color, third_color]
legend_handles = [plt.Line2D([0], [0], marker='s', color='White', label=label, 
                             markersize=14, markerfacecolor=color, linestyle='None') 
                  for label, color in zip(legend_labels, legend_colors)]
legend = ax.legend(handles=legend_handles, title='Dataset contained in', fontsize='large', title_fontsize='x-large', labelspacing=0.9, borderpad=1, facecolor='white', loc='lower left')

# more legend modifications
legend.get_frame().set_boxstyle("square")
legend.get_frame().set_edgecolor('black') 
legend.get_frame().set_linewidth(1)

# set a background color
ax.set_facecolor('lightgrey')

# change axis limits so the US is centered
ax.set_ylim(22, 53)
ax.set_xlim(-126, -66)

# show the plot
plt.show()

# %%
# Assuming 'shopping' is your DataFrame and it has a 'Location' column for states,
# and a 'Purchase Amount (USD)' column for the purchase amounts.

# Group by 'Location' and sum the 'Purchase Amount (USD)'
state_purchase_totals = shopping.groupby('Location')['Purchase Amount (USD)'].sum()

# Sort the states by the total purchase amount in descending order
states_order = state_purchase_totals.sort_values(ascending=False).head(25).index

# %%
# plotting the top states for haunted places

# set up plot and styles
f, ax = plt.subplots(figsize=(12, 8))
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')

# Set up filter for states to be in descending order
#states_order = shopping['Location'].value_counts().head(25).index

# establish the plot
sns.countplot(y="Location", data=shopping, palette="turbo", order=states_order, ax=ax)

# set overall plot title
ax.set_title('Most frequent states for personal accounts', fontsize=16, weight='bold', style='italic', y=1)

# set x label
ax.set_xlabel('Number of Haunted Places', weight='bold', style='italic', size=12)

# set a custom y-axis label for `state`
ax.text(-0.001, 1.015, 'State', weight='bold', size=10, style='italic',
            verticalalignment='center', horizontalalignment='right', transform=ax.transAxes)
# make default y-axis overall label disappear so it doesn't interfere with the custom y-axis label
ax.set_ylabel('')

# set background color
ax.set_facecolor('lightgrey')

# make y-axis label bold
for label in ax.get_yticklabels():
    label.set_weight('bold')

# show the plot
plt.show()

# %%
# Plot: Most-shopped locations
states_order = shopping['Location'].value_counts().head(50).index  # create a descending-order parameter
f, ax = plt.subplots(figsize=(14, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.countplot(x="Location", data=shopping, order=states_order, color='teal', ax=ax)  # set up the countplot
ax.set_title('Top 10 Most-shopped Locations', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Location', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('white')  # set a background color
#for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), weight='bold', rotation=45)  # set up the outerwear plot's y-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))  # customize the legend placement
plt.show()  # show the plot

# %%
# Assuming 'shopping' is your DataFrame and it has a 'Location' column for states,
# and a 'Purchase Amount (USD)' column for the purchase amounts.

# Group by 'Location' and sum the 'Purchase Amount (USD)'
state_purchase_totals = shopping.groupby('Location')['Purchase Amount (USD)'].sum()

# Sort the states by the total purchase amount in descending order
states_order = state_purchase_totals.sort_values(ascending=False).head(25).index

# %%
# Plot: Most-shopped locations
#states_order = shopping['Location'].value_counts().head(50).index  # create a descending-order parameter
f, ax = plt.subplots(figsize=(14, 2))  # set up plot and styles
plt.subplots_adjust(hspace=0.3, wspace=0.5)
sns.set_style('white')
sns.barplot(x="Location", y='Previous Purchases', data=shopping, color='teal', ax=ax)  # set up the countplot
ax.set_title('Top 10 Most-shopped Locations', fontsize=14, weight='bold', style='italic', y=1)  # set a title
ax.set_xlabel('Location', weight='bold', style='italic', size=12)  # customize x-axis label
ax.set_ylabel('Count', weight='bold', style='italic', size=12)  # customize y-axis label
ax.set_facecolor('white')  # set a background color
#for label in ax.get_xticklabels(): label.set_weight('bold')  # customize x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), weight='bold', rotation=45)  # set up the outerwear plot's y-axis tick labels
for label in ax.get_yticklabels(): label.set_weight('bold')  # customize y-axis tick labels
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))  # customize the legend placement
plt.show()  # show the plot

# %% [markdown]
# review rating ~ size, color, shipping type
